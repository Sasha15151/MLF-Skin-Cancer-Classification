# %%
# !git clone https://github.com/Sasha15151/MLF-Skin-Cancer-Classification.git
# Out:
# Cloning into 'MLF-Skin-Cancer-Classification'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 51 (delta 7), reused 28 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.58 KiB | 4.86 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# TO DO: change the user email and user name into yours
# !git config --global user.email "wangsasha55@gmail.com"
# !git config --global user.name "Sasha15151"

# %%
# change the printing statement
import os
print('new printing')

# %%
# open the repo
import os
os.chdir('/content/MLF-Skin-Cancer-Classification')

# %%
# checking whether we opened repo
# !ls

# %%
# TO DO: write the branch name after the -b
# !git checkout -b

# %%
# select the document to change
# !git add notebooks/01_data_cleaning.ipynb

# %%
# check the status, see whether we made the change
# !git status

# %%
# write the commit message
# !git commit -m "update print statement"

# %% [markdown]
# Get the token in github - Settings - Developer Settings -Personal Access tokens - tokens(classic) - Generate new token (classic); select a time for token to be valid; copied down the token once you see it, paste it to somewhere cause you will only see it once.

# %%
# TO DO:
# 1. get the github token, save it into the "Secrets" in colab with "Name": "GITHUB_TOKEN" and Value be the token copied down from github
# 2. change the username into yours
# 3. change the branch_name
from google.colab import userdata

token = userdata.get('GITHUB_TOKEN')

username = "Sasha15151"
repo_name = "MLF-Skin-Cancer-Classification"
branch_name = "setting"

remote_url = f"https://{token}@github.com/{username}/{repo_name}.git"

print("successfully got your token and set the remote url!")

# %%
# !git push {remote_url} {branch_name}
